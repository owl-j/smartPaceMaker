# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = open("ADCPoll_21052021_1", "r")
a = []
f.readline()
for x in f:
    a.append(int(x))
plt.plot(a[100:])

# %%
# Out:
# [3087,
#  3135,
#  3139,
#  3157,
#  3135,
#  3115,
#  3107,
#  3063,
#  3111,
#  3175,
#  3063,
#  3135,
#  3107,
#  3171,
#  3155,
#  3063,
#  3121,
#  3063,
#  3063,
#  3167,
#  3139,
#  3127,
#  3167,
#  3106,
#  3163,
#  3095,
#  3147,
#  3091,
#  3189,
#  3107,
#  3167,
#  3073,
#  3151,
#  3079,
#  3186,
#  3126,
#  3154,
#  3139,
#  3167,
#  3173,
#  3150,
#  3095,
#  3173,
#  3070,
#  3086,
#  3179,
#  3077,
#  3071,
#  3144,
#  3063,
#  3095,
#  30711,
#  0,
#  0,
#  2,
#  7,
#  13,
#  4,
#  0,
#  3,
#  7,
#  12,
#  0,
#  9,
#  6,
#  15,
#  0,
#  6,
#  2,
#  7,
#  7,
#  12,
#  13,
#  10,
#  0,
#  6,
#  0,
#  0,
#  8,
#  2,
#  3,
#  8,
#  10,
#  11,
#  13,
#  0,
#  4,
#  9,
#  5,
#  8,
#  7,
#  7,
#  9,
#  3,
#  6,
#  2,
#  5,
#  8,
#  4,
#  5,
#  7,
#  7,
#  9,
#  8,
#  5,
#  8,
#  7,
#  5,
#  9,
#  20,
#  6,
#  6,
#  4,
#  0,
#  5,
#  6,
#  15,
#  6,
#  5,
#  9,
#  7,
#  14,
#  0,
#  5,
#  9,
#  5,
#  5,
#  8,
#  2,
#  10,
#  12,
#  3,
#  7,
#  6,
#  6,
#  10,
#  8,
#  5,
# ...
